# %%
import pandas as pd
    
df = pd.read_excel(r"C:\Users\Tasmi\Downloads\excel downloaded\Customer Call List.xlsx")
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df = df.drop_duplicates()
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df = df.drop(columns = "Not_Useful_Column")
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df["Last_Name"].str.strip()
# Out:
# 0         Baggins
# 1           Nadir
# 2          /White
# 3         Schrute
# 4            Snow
# 5         Swanson
# 6          Winger
# 7          Holmes
# 8             NaN
# 9          Parker
# 10         Gamgee
# 11      ...Potter
# 12         Draper
# 13          Knope
# 14    Flenderson_
# 15        Weasley
# 16          Scott
# 17           Kent
# 18         Braton
# 19      Skywalker
# Name: Last_Name, dtype: object

# %%
df["Last_Name"].str.lstrip("...")
# Out:
# 0         Baggins
# 1           Nadir
# 2          /White
# 3         Schrute
# 4            Snow
# 5         Swanson
# 6          Winger
# 7          Holmes
# 8             NaN
# 9          Parker
# 10         Gamgee
# 11         Potter
# 12         Draper
# 13          Knope
# 14    Flenderson_
# 15        Weasley
# 16          Scott
# 17           Kent
# 18         Braton
# 19      Skywalker
# Name: Last_Name, dtype: object

# %%
df["Last_Name"] = df["Last_Name"].str.lstrip("...")
df["Last_Name"] = df["Last_Name"].str.lstrip("/")
df["Last_Name"] = df["Last_Name"].str.rstrip("_")
df["Last_Name"] = df["Last_Name"].str.strip("123._/")

df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123/643/9775
# 2         1003     Walter       White    7066950392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876|678|3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger           NaN
# 7         1008   Sherlock      Holmes  876|678|3469
# 8         1009    Gandalf         NaN           N/a
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee           NaN
# 11        1012      Harry      Potter    7066950392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876|678|3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123/643/9775
# ...

# %%
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123/643/9775
# 2         1003     Walter       White    7066950392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876|678|3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger           NaN
# 7         1008   Sherlock      Holmes  876|678|3469
# 8         1009    Gandalf         NaN           N/a
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee           NaN
# 11        1012      Harry      Potter    7066950392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876|678|3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123/643/9775
# ...

# %%
#df["Phone_Number"] = df["Phone_Number"].str.replace(r'-', '', regex=True)

#df["Phone_Number"].apply(lambda x: x[0:3] + '-' + x[3:6] + '-' + x[6:10])

#df["Phone_Number"] = df["Phone_Number"].apply(lambda x: str(x))

#df["Phone_Number"] = df["Phone_Number"].str.replace('nan--','')

#df["Phone_Number"] = df["Phone_Number"].str.replace('nan','')

#df["Phone_Number"] = df["Phone_Number"].str.replace('N/a','')

df["Phone_Number"] = df["Phone_Number"].str.replace('/', '')

df["Phone_Number"] = df["Phone_Number"].str.replace('|', '', regex=False)

df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins   1235455421
# 1         1002       Abed       Nadir   1236439775
# 2         1003     Walter       White
# 3         1004     Dwight     Schrute   1235432345
# 4         1005        Jon        Snow   8766783469
# 5         1006        Ron     Swanson   3047622467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes   8766783469
# 8         1009    Gandalf         NaN
# 9         1010      Peter      Parker   1235455421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter
# 12        1013        Don      Draper   1235432345
# 13        1014     Leslie       Knope   8766783469
# 14        1015       Toby  Flenderson   3047622467
# 15        1016        Ron     Weasley   1235455421
# 16        1017   Michael        Scott   1236439775
# 17        1018      Clark        Kent
# 18        1019      Creed      Braton
# ...

# %%
df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins   1235455421
# 1         1002       Abed       Nadir   1236439775
# 2         1003     Walter       White
# 3         1004     Dwight     Schrute   1235432345
# 4         1005        Jon        Snow   8766783469
# 5         1006        Ron     Swanson   3047622467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes   8766783469
# 8         1009    Gandalf         NaN
# 9         1010      Peter      Parker   1235455421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter
# 12        1013        Don      Draper   1235432345
# 13        1014     Leslie       Knope   8766783469
# 14        1015       Toby  Flenderson   3047622467
# 15        1016        Ron     Weasley   1235455421
# 16        1017   Michael        Scott   1236439775
# 17        1018      Clark        Kent
# 18        1019      Creed      Braton
# ...

# %%
df[["Street_Address", "State", "Zip_Code"]] = df['Address'].str.split(pat=",", n=2, expand=True)
df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins   1235455421
# 1         1002       Abed       Nadir   1236439775
# 2         1003     Walter       White
# 3         1004     Dwight     Schrute   1235432345
# 4         1005        Jon        Snow   8766783469
# 5         1006        Ron     Swanson   3047622467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes   8766783469
# 8         1009    Gandalf         NaN
# 9         1010      Peter      Parker   1235455421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter
# 12        1013        Don      Draper   1235432345
# 13        1014     Leslie       Knope   8766783469
# 14        1015       Toby  Flenderson   3047622467
# 15        1016        Ron     Weasley   1235455421
# 16        1017   Michael        Scott   1236439775
# 17        1018      Clark        Kent
# 18        1019      Creed      Braton
# ...

# %%
df["Paying Customer"] = df["Paying Customer"].str.replace('Yes', 'Y')

df["Paying Customer"] = df["Paying Customer"].str.replace('No', 'N')
df
# Out:
#                  CustomerID First_Name   Last_Name Phone_Number  \
# 0                    1001.0      Frodo     Baggins   1235455421
# 1                    1002.0       Abed       Nadir   1236439775
# 2                    1003.0     Walter       White
# 3                    1004.0     Dwight     Schrute   1235432345
# 4                    1005.0        Jon        Snow   8766783469
# 5                    1006.0        Ron     Swanson   3047622467
# 6                    1007.0       Jeff      Winger
# 7                    1008.0   Sherlock      Holmes   8766783469
# 8                    1009.0    Gandalf         NaN
# 9                    1010.0      Peter      Parker   1235455421
# 10                   1011.0    Samwise      Gamgee
# 11                   1012.0      Harry      Potter
# 12                   1013.0        Don      Draper   1235432345
# 13                   1014.0     Leslie       Knope   8766783469
# 14                   1015.0       Toby  Flenderson   3047622467
# ...

# %%
df["Do_Not_Contact"] = df["Do_Not_Contact"].str.replace('Yes', 'Y')

df["Do_Not_Contact"] = df["Do_Not_Contact"].str.replace('No', 'N')
df
# Out:
#                  CustomerID First_Name   Last_Name Phone_Number  \
# 0                    1001.0      Frodo     Baggins   1235455421
# 1                    1002.0       Abed       Nadir   1236439775
# 2                    1003.0     Walter       White
# 3                    1004.0     Dwight     Schrute   1235432345
# 4                    1005.0        Jon        Snow   8766783469
# 5                    1006.0        Ron     Swanson   3047622467
# 6                    1007.0       Jeff      Winger
# 7                    1008.0   Sherlock      Holmes   8766783469
# 8                    1009.0    Gandalf         NaN
# 9                    1010.0      Peter      Parker   1235455421
# 10                   1011.0    Samwise      Gamgee
# 11                   1012.0      Harry      Potter
# 12                   1013.0        Don      Draper   1235432345
# 13                   1014.0     Leslie       Knope   8766783469
# 14                   1015.0       Toby  Flenderson   3047622467
# ...

# %%
#df = df.replace('N/a',',')

#df = df.replace('NaN',',') #NaN can't be replaced hence we used fillna

df = df.fillna('')
df
# Out:
#                 CustomerID First_Name   Last_Name Phone_Number  \
# 0                   1001.0      Frodo     Baggins   1235455421
# 1                   1002.0       Abed       Nadir   1236439775
# 2                   1003.0     Walter       White
# 3                   1004.0     Dwight     Schrute   1235432345
# 4                   1005.0        Jon        Snow   8766783469
# 5                   1006.0        Ron     Swanson   3047622467
# 6                   1007.0       Jeff      Winger
# 7                   1008.0   Sherlock      Holmes   8766783469
# 8                   1009.0    Gandalf
# 9                   1010.0      Peter      Parker   1235455421
# 10                  1011.0    Samwise      Gamgee
# 11                  1012.0      Harry      Potter
# 12                  1013.0        Don      Draper   1235432345
# 13                  1014.0     Leslie       Knope   8766783469
# 14                  1015.0       Toby  Flenderson   3047622467
# ...

# %%
import re

df_filtered = df[df["Phone_Number"].str.match(r'^\d{10}$')]  

#to get rid of blank number cells from call list but it never executed

# %%
df
# Out:
#                 CustomerID First_Name   Last_Name Phone_Number  \
# 0                   1001.0      Frodo     Baggins   1235455421
# 1                   1002.0       Abed       Nadir   1236439775
# 2                   1003.0     Walter       White
# 3                   1004.0     Dwight     Schrute   1235432345
# 4                   1005.0        Jon        Snow   8766783469
# 5                   1006.0        Ron     Swanson   3047622467
# 6                   1007.0       Jeff      Winger
# 7                   1008.0   Sherlock      Holmes   8766783469
# 8                   1009.0    Gandalf
# 9                   1010.0      Peter      Parker   1235455421
# 10                  1011.0    Samwise      Gamgee
# 11                  1012.0      Harry      Potter
# 12                  1013.0        Don      Draper   1235432345
# 13                  1014.0     Leslie       Knope   8766783469
# 14                  1015.0       Toby  Flenderson   3047622467
# ...

# %%
for x in df.index:
    if df.loc[x, "Do_Not_Contact"] == 'Y':
        df.drop (x, inplace=True)
        
df
# Out:
#                 CustomerID First_Name   Last_Name Phone_Number  \
# 0                   1001.0      Frodo     Baggins   1235455421
# 2                   1003.0     Walter       White
# 4                   1005.0        Jon        Snow   8766783469
# 6                   1007.0       Jeff      Winger
# 7                   1008.0   Sherlock      Holmes   8766783469
# 8                   1009.0    Gandalf
# 9                   1010.0      Peter      Parker   1235455421
# 10                  1011.0    Samwise      Gamgee
# 11                  1012.0      Harry      Potter
# 12                  1013.0        Don      Draper   1235432345
# 13                  1014.0     Leslie       Knope   8766783469
# 14                  1015.0       Toby  Flenderson   3047622467
# 15                  1016.0        Ron     Weasley   1235455421
# 16                  1017.0   Michael        Scott   1236439775
# 17                  1018.0      Clark        Kent
# ...

# %%
df["Do_Not_Contact"].str.replace('','N')
# Out:
# 0                  NNN
# 2                    N
# 4                  NNN
# 6                  NNN
# 7                  NNN
# 8                    N
# 9                  NNN
# 10                 NNN
# 11                   N
# 12                 NNN
# 13                 NNN
# 14                 NNN
# 15                 NNN
# 16                 NNN
# 17                   N
# 19                 NNN
# Do_Not_Contact       N
# Paying Customer      N
# Name: Do_Not_Contact, dtype: object

# %%
for x in df.index:
    if df.loc[x, "Phone_Number"] == '':
        df.drop (x, inplace=True)
        
df
# Out:
#    CustomerID First_Name   Last_Name Phone_Number  \
# 0      1001.0      Frodo     Baggins   1235455421
# 4      1005.0        Jon        Snow   8766783469
# 7      1008.0   Sherlock      Holmes   8766783469
# 9      1010.0      Peter      Parker   1235455421
# 12     1013.0        Don      Draper   1235432345
# 13     1014.0     Leslie       Knope   8766783469
# 14     1015.0       Toby  Flenderson   3047622467
# 15     1016.0        Ron     Weasley   1235455421
# 16     1017.0   Michael        Scott   1236439775
# 19     1020.0     Anakin   Skywalker   8766783469
#
#                            Address Paying Customer Do_Not_Contact  \
# 0            123 Shire Lane, Shire               Y              N
# 4                 123 Dragons Road               Y              N
# 7                    98 Clue Drive               N              N
# 9       25th Main Street, New York               Y              N
# 12                2039 Main Street               Y              N
# ...

# %%
#another way to drop null values
#df = df.dropna(subset="Phone_Number"), inplace=True

# %%
df = df.reset_index(drop=True)
df
# Out:
#   CustomerID First_Name   Last_Name Phone_Number  \
# 0     1001.0      Frodo     Baggins   1235455421
# 1     1005.0        Jon        Snow   8766783469
# 2     1008.0   Sherlock      Holmes   8766783469
# 3     1010.0      Peter      Parker   1235455421
# 4     1013.0        Don      Draper   1235432345
# 5     1014.0     Leslie       Knope   8766783469
# 6     1015.0       Toby  Flenderson   3047622467
# 7     1016.0        Ron     Weasley   1235455421
# 8     1017.0   Michael        Scott   1236439775
# 9     1020.0     Anakin   Skywalker   8766783469
#
#                           Address Paying Customer Do_Not_Contact  \
# 0           123 Shire Lane, Shire               Y              N
# 1                123 Dragons Road               Y              N
# 2                   98 Clue Drive               N              N
# 3      25th Main Street, New York               Y              N
# 4                2039 Main Street               Y              N
# ...
